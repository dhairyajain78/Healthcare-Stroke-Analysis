# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("healthcare.csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['age'] = df['age'].astype(int)
df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.215264      0.097456       0.054012
# std    21161.721625    22.633866      0.296607       0.226063
# min       67.000000     0.000000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
x = round(df['bmi'].mean(), 2)
df.fillna(x, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   int64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 479.2+ KB

# %%
df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level    bmi   smoking_status  \
# 0           Private          Urban             228.69  36.60  formerly smoked
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Tasks :-
# 1. Analyze patient demographics

# %%
x = df['gender'].value_counts()
x
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
y = df['age'].value_counts()
y
# Out:
# age
# 78    102
# 57     95
# 52     90
# 54     87
# 51     86
#      ...
# 11     36
# 10     35
# 4      34
# 7      32
# 6      24
# Name: count, Length: 83, dtype: int64

# %% [markdown]
# 2. Identify major risk factors

# %%
ds=df.groupby(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi'])['stroke'].mean()
ds
# Out:
# age  hypertension  heart_disease  avg_glucose_level  bmi
# 0    0             0              55.86              16.0    0.0
#                                   57.02              20.7    0.0
#                                   57.09              19.4    0.0
#                                   58.35              18.6    0.0
#                                   60.40              17.3    0.0
#                                                             ...
# 82   1             0              227.28             33.3    0.0
#                    1              73.19              33.5    0.0
#                                   84.03              26.5    1.0
#                                   101.56             31.5    0.0
#                                   215.94             27.9    1.0
# Name: stroke, Length: 5110, dtype: float64

# %% [markdown]
# 3. Analyze BMI distribution

# %%
df.groupby('age')['bmi'].mean().round(2)
# Out:
# age
# 0     18.43
# 1     19.32
# 2     19.09
# 3     19.06
# 4     18.10
#       ...
# 78    28.01
# 79    27.96
# 80    28.79
# 81    27.95
# 82    28.04
# Name: bmi, Length: 83, dtype: float64

# %%
df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level    bmi   smoking_status  \
# 0           Private          Urban             228.69  36.60  formerly smoked
# ...

# %% [markdown]
# Analyze smoking habits

# %%
x = df.groupby('gender')['smoking_status'].value_counts()
x
# Out:
# gender  smoking_status
# Female  never smoked       1229
#         Unknown             836
#         formerly smoked     477
#         smokes              452
# Male    Unknown             708
#         never smoked        663
#         formerly smoked     407
#         smokes              337
# Other   formerly smoked       1
# Name: count, dtype: int64

# %% [markdown]
# 5. find healthcare insights

# %%
df.groupby(['hypertension', 'heart_disease', 'avg_glucose_level'])['stroke'].mean()
# Out:
# hypertension  heart_disease  avg_glucose_level
# 0             0              55.12                0.0
#                              55.22                0.0
#                              55.23                0.0
#                              55.25                0.0
#                              55.26                0.0
#                                                  ...
# 1             1              246.53               0.0
#                              247.51               1.0
#                              250.89               1.0
#                              254.63               0.0
#                              271.74               1.0
# Name: stroke, Length: 4185, dtype: float64

# %%
df.groupby('bmi')['stroke'].mean().round(2)
# Out:
# bmi
# 10.3    0.0
# 11.3    0.0
# 11.5    0.0
# 12.0    0.0
# 12.3    0.0
#        ...
# 66.8    0.0
# 71.9    0.0
# 78.0    0.0
# 92.0    0.0
# 97.6    0.0
# Name: stroke, Length: 419, dtype: float64

# %%
df.groupby('smoking_status')['stroke'].sum()
# Out:
# smoking_status
# Unknown            47
# formerly smoked    70
# never smoked       90
# smokes             42
# Name: stroke, dtype: int64

# %% [markdown]
# Expected Visualizations:

# %% [markdown]
# HISTOGRAMS

# %%
sns.histplot(df['age'] , bins=50 , kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['avg_glucose_level'] , bins=50 , kde=True)
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='Count'>

# %%
sns.histplot(df['bmi'] , bins=50 , kde=True)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %% [markdown]
# BOXPLOT

# %%
sns.boxplot(x='stroke' , y='age' , data =df , palette = 'rainbow')
# Out:
# C:\Users\rajender jain\AppData\Local\Temp\ipykernel_34684\2074691873.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='stroke' , y='age' , data =df , palette = 'rainbow')
# <Axes: xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x='stroke' , y='age' , data =df , color ='beige')
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x='stroke' , y='avg_glucose_level' ,color='pink',  data =df)
# Out:
# <Axes: xlabel='stroke', ylabel='avg_glucose_level'>

# %% [markdown]
# VOILIN PLOT

# %%
sns.violinplot(x='stroke' , y='age' , data =df , palette = 'rainbow')
# Out:
# C:\Users\rajender jain\AppData\Local\Temp\ipykernel_34684\4169655542.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='stroke' , y='age' , data =df , palette = 'rainbow')
# <Axes: xlabel='stroke', ylabel='age'>

# %%
sns.violinplot(x='stroke' , y='bmi' , data =df , palette = 'rainbow')
# Out:
# C:\Users\rajender jain\AppData\Local\Temp\ipykernel_34684\2124604470.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='stroke' , y='bmi' , data =df , palette = 'rainbow')
# <Axes: xlabel='stroke', ylabel='bmi'>

# %%
sns.violinplot(x='stroke' , y='avg_glucose_level' , data =df , palette = 'rainbow')
# Out:
# C:\Users\rajender jain\AppData\Local\Temp\ipykernel_34684\2350729403.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='stroke' , y='avg_glucose_level' , data =df , palette = 'rainbow')
# <Axes: xlabel='stroke', ylabel='avg_glucose_level'>

# %% [markdown]
# PAIR PLOTS

# %%
col=['age','bmi','avg_glucose_level','stroke']
sns.pairplot(df[col] , hue='stroke')
plt.show()
